# %%
import pandas as pd

# %%
heart = pd.read_csv("heart.csv")

# %%
nRow, nCol = heart.shape

# %%
heart.head(5)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# # Selecting a single column by label

# %%
# select the column (age) using dot notation
age1 = heart.age

# select the column (age) using square brackets
age2 = heart['age']

print(type(age))

print(type(age2))

age1

#"age2" to show "age2 = heart['age']"
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
#Series object
#heart['age']

#DataFrame object
heart.head(5)[['age']]
# Out:
#    age
# 0   63
# 1   37
# 2   41
# 3   56
# 4   57

# %% [markdown]
# # Selecting multiple columns by label

# %%
# select multiple columns by passing in a list with the column names to the indexing operator
heart[['age', 'cp']]
# Out:
#      age  cp
# 0     63   3
# 1     37   2
# 2     41   1
# 3     56   1
# 4     57   0
# ..   ...  ..
# 298   57   0
# 299   45   3
# 300   68   0
# 301   57   0
# 302   57   1
#
# [303 rows x 2 columns]

# %% [markdown]
# # Selecting colums by data type

# %%
import numpy as np

# select numeric columns - numpy object
numeric_inputs = heart.select_dtypes(include=np.number)

# check selected columns with the .columns attribute
numeric_inputs.columns
# Index(['salary'], dtype='object')

# the method returns a DataFrame object
print(type(numeric_inputs))
# <class 'pandas.core.frame.DataFrame'>

# select numeric columns - string
#numeric_inputs_2 = heart.select_dtypes(include='number')

# check selected columns with the .columns attribute
#numeric_inputs_2.columns
# Index(['salary'], dtype='object')

# the method returns a DataFrame object
#print(type(numeric_inputs_2))
# <class 'pandas.core.frame.DataFrame'>

# visualize the data frame
numeric_inputs.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
# concise summary of the data frame, including the column names and their data types
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# check the data types of the columns
heart.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %% [markdown]
# # Selecting a single row by label

# %%
heart.index

# select the employee with id number 1 with the .loc[] indexer
heart.loc[30]
# Out:
# age          41.0
# sex           0.0
# cp            1.0
# trtbps      105.0
# chol        198.0
# fbs           0.0
# restecg       1.0
# thalachh    168.0
# exng          0.0
# oldpeak       0.0
# slp           2.0
# caa           1.0
# thall         2.0
# output        1.0
# Name: 30, dtype: float64

# %%
# select the employee with id number 30 with the .loc[] indexer, providing a single-element list
heart.loc[[30]]
# Out:
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 30   41    0   1     105   198    0        1       168     0      0.0    2
#
#     caa  thall  output
# 30    1      2       1

# %% [markdown]
# # Selecting multiple rows by label

# %%
# select the employees with id number 30 and 50 with the .loc[] indexer
heart.loc[[30, 50]]
# Out:
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 30   41    0   1     105   198    0        1       168     0      0.0    2
# 50   51    0   2     130   256    0        0       149     0      0.5    2
#
#     caa  thall  output
# 30    1      2       1
# 50    0      2       1

# %% [markdown]
# # Selecting a single row by position

# %%
# select the first row of the data frame
heart.iloc[[0]]
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
#
#    caa  thall  output
# 0    0      1       1

# %%
# select the last row of the data frame - input: integer - output: series
heart.iloc[[-1]]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 302    1      2       0

# %% [markdown]
# # Selecting multiple rows by position

# %%
# select the first five rows of the dataframe using a list
heart.iloc[[0, 1, 2, 3, 4]]
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
# select the first five rows of the dataframe using slice notation
heart.iloc[0:5]
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# # Selecting rows and columns simultaneously

# %%
# select the age of the employee with id number 30 by label
heart.loc[30, 'age']
# Out:
# 41

# %% [markdown]
# Selecting a row and multiple columns

# %%
# select the age, sex, and cp of the employee with id number 30 by position
#heart.iloc[30, [0, 1, 2]]

# select the age, sex, and cp of the employee with id number 478 by label
heart.loc[30, ['age', 'sex', 'cp']]
# Out:
# age    41.0
# sex     0.0
# cp      1.0
# Name: 30, dtype: float64

# %% [markdown]
# Selecting disjointed rows and columns

# %%
# select the age, sex, and cp of the employees with id number 0 and 30 by position
#heart.iloc[[0, 30], [0, 1, 2]]

# select the age, sex, and cp of the employees with id number 0 and 30 by label
heart.loc[[0, 30], ['age', 'sex', 'cp']]
# Out:
#     age  sex  cp
# 0    63    1   3
# 30   41    0   1

# %% [markdown]
# Selecting continuous rows and columns

# %%
# select the age, sex, and cp of the employees with id number 0, 1, 2, 3 by position
#heart.iloc[:3, [0, 1, 2]]

# select the age, sex, and cp of the employees with id number 0, 1, 2, 3 by label
heart.loc[:3, ['age', 'sex', 'cp']]
# Out:
#    age  sex  cp
# 0   63    1   3
# 1   37    1   2
# 2   41    0   1
# 3   56    1   1

# %% [markdown]
# # Selecting a scalar value using the .at[] and .iat[] indexers

# %%
# select the age of the employee with id number 0 by position
#heart.iat[0, 0]

# select the age of the employee with id number 0 by label
heart.at[0, 'age']
# Out:
# 63

# %% [markdown]
# .at[] and .iat[] indexers can only be used to access a single value, raising a type error when trying to select multiple elements of the data frame.

# %% [markdown]
# # Selecting rows using Boolean selection

# %%
#age greater than 60
heart['age'] > 60
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300     True
# 301    False
# 302    False
# Name: age, Length: 303, dtype: bool

# %%
#age greater than 60
heart[heart['age'] > 60]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 13    64    1   3     110   211    0        0       144     1      1.8    1
# 17    66    0   3     150   226    0        1       114     0      2.6    0
# 19    69    0   3     140   239    0        1       151     0      1.8    2
# 23    61    1   2     150   243    1        1       137     1      1.0    1
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 290   61    1   0     148   203    0        1       161     0      0.0    2
# 293   67    1   2     152   212    0        0       150     0      0.8    1
# 295   63    1   0     140   187    0        0       144     1      4.0    2
# 296   63    0   0     124   197    0        1       136     1      0.0    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
# age greater than 60 and sex == 1
heart[(heart['age'] > 60) & (heart['sex'] == 1)]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 13    64    1   3     110   211    0        0       144     1      1.8    1
# 23    61    1   2     150   243    1        1       137     1      1.0    1
# 31    65    1   0     120   177    0        1       140     0      0.4    2
# 51    66    1   0     120   302    0        0       151     0      0.4    1
# 52    62    1   2     130   231    0        1       146     0      1.8    1
# 86    68    1   2     118   277    0        1       151     0      1.0    2
# 106   69    1   3     160   234    1        0       131     0      0.1    1
# 137   62    1   1     128   208    1        0       140     0      0.0    2
# 139   64    1   0     128   263    0        1       105     1      0.2    1
# 145   70    1   1     156   245    0        0       143     0      0.0    2
# ...

# %% [markdown]
# isin method

# %%
# select sex == 0 and 1 using the isin method
heart[heart['sex'].isin([0, 1])]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %% [markdown]
# between method

# %%
#age between 55 and 60
heart[heart['age'].between(55, 60)]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# 5     57    1   0     140   192    0        1       148     0      0.4    1
# 6     56    0   1     140   294    0        0       153     0      1.3    1
# 9     57    1   2     150   168    0        1       174     0      1.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 292   58    0   0     170   225    1        0       146     1      2.8    1
# 297   59    1   0     164   176    1        0        90     0      1.0    1
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 3      0      2       1
# ...

# %%
heart
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %% [raw]
# sex: 1=male, 0=female
#
# chest pain type:
# -- Value 1: typical angina
# -- Value 2: atypical angina
# -- Value 3: non-anginal pain
# -- Value 4: asymptomatic
#
# resting blood pressure: (in mm Hg on admission to the hospital)
#
# cholestoral: in mg/dl
#
# fasting blood sugar >120 mg/dl (1=true, 0=false)
#
# restecg:
# Value 0:normal
# Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
#
# exercise include angina (1=yes, 0=no)
#
# oldpeak = ST depression induced by exercise relative to rest

# %%
from matplotlib import pyplot as plt

# %%
heart.hist(column='age');f

# %%
heart.hist(column='cp');

# %%
heart.hist(column='sex');

# %%
bins = [20, 30, 40, 50, 60, 70, 80]
plt.hist(age, bins=bins, edgecolor='black');

# %%
heart.boxplot(column=['age']);
